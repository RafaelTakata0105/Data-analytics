# %% [markdown]
# # Intro to predictive models

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
x, y = make_regression(n_features= 1, noise= 30, random_state= 0)
df = pd.DataFrame(x)
df.columns = ['x']
df['y'] = y
df
# Out:
#            x          y
# 0  -0.359553 -29.387972
# 1   0.976639 -18.771359
# 2   0.402342   0.563777
# 3  -0.813146  19.905024
# 4  -0.887786 -31.843421
# ..       ...        ...
# 95 -1.165150 -46.555436
# 96 -0.362741  29.346690
# 97  0.356366   5.143858
# 98 -1.613898 -21.482798
# 99 -1.180632 -66.176710
#
# [100 rows x 2 columns]

# %%
df['x'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
y_mean = np.array([y.mean()]*100)
y_mean[0] #No importa porque todos son el mismo
# Out:
# 0.1344193000112442

# %%
model_1 = LinearRegression()
model_2 = LinearRegression()
model_3 = LinearRegression()

model_1.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = model_1.predict(x)

# %%
#Selecetor
plt.figure(figsize=(10,3))
#Datos a graficar
plt.scatter(x, y, label = 'Random Data')
#Graficar el promedio
plt.plot(x, y_mean, label = 'Mean', c = 'red')
#Graficar el linear regression
plt.plot(x, y_pred, label = 'linear regression', c = 'black')
#Formato del show
plt.title('Scatter Example plot')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend()

plt.savefig('../reports/figures/random.svg')

# %% [markdown]
# # Activity

# %%
df = pd.read_csv('../data/raw/BostonHousing.csv')
df.head(3)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %%
x1 = df['rm'].to_numpy().reshape(-1,1)
y1 = df['medv'].to_numpy().reshape(-1, 1)
y2 = df['lstat'].to_numpy().reshape(-1, 1)
x1
# Out:
# array([[6.575],
#        [6.421],
#        [7.185],
#        [6.998],
#        [7.147],
#        [6.43 ],
#        [6.012],
#        [6.172],
#        [5.631],
#        [6.004],
#        [6.377],
#        [6.009],
#        [5.889],
#        [5.949],
#        [6.096],
#        [5.834],
#        [5.935],
#        [5.99 ],
#        [5.456],
#        [5.727],
#        [5.57 ],
#        [5.965],
#        [6.142],
#        [5.813],
#        [5.924],
#        [5.599],
#        [5.813],
#        [6.047],
#        [6.495],
#        [6.674],
#        [5.713],
#        [6.072],
#        [5.95 ],
#        [5.701],
#        [6.096],
#        [5.933],
#        [5.841],
#        [5.85 ],
#        [5.966],
#        [6.595],
#        [7.024],
#        [6.77 ],
#        [6.169],
#        [6.211],
#        [6.069],
#        [5.682],
#        [5.786],
#        [6.03 ],
#        [5.399],
#        [5.602],
#        [5.963],
#        [6.115],
#        [6.511],
#        [5.998],
#        [5.888],
# ...

# %%
model_2.fit(x1, y1)
# Out:
# LinearRegression()

# %%
model_3.fit(x1, y2)
# Out:
# LinearRegression()

# %%
y1_mean = np.array([y1.mean()]*len(df))

# %%
y1_pred = model_2.predict(x1)

# %%
y2_pred = model_3.predict(x1)

# %%
#Selecetor
plt.figure(figsize=(10,3))
#Datos a graficar
plt.scatter(x1, y1, y2,  label = 'Housing Values in Suburbs of Boston')
#Graficar el promedio
plt.plot(x1, y1_mean, label = 'Mean', c = 'red')
#Graficar el linear regression
plt.plot(x1, y1_pred, label = 'linear regression', c = 'black')
#Formato del show
plt.title('Rafael Takata')
plt.xlabel('RM')
plt.ylabel('Medv')
plt.legend()

plt.savefig('../reports/figures/rafael_takata.png')
